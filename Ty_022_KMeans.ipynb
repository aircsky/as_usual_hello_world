# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.rand(200,2)

# %%
plt.scatter(X[:,0],X[:,1],s=100)

# %%
from sklearn.cluster import KMeans

# %%
clf = KMeans(n_clusters=4)

# %%
clf.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clf.labels_
# Out:
# array([0, 3, 2, 2, 1, 3, 0, 1, 1, 3, 3, 0, 2, 3, 2, 2, 1, 2, 1, 2, 0, 3,
#        2, 2, 1, 3, 1, 2, 0, 2, 1, 3, 0, 0, 1, 2, 2, 0, 3, 1, 3, 3, 1, 2,
#        1, 2, 3, 3, 1, 3, 3, 3, 1, 1, 0, 3, 0, 2, 2, 1, 3, 0, 3, 3, 0, 2,
#        1, 0, 3, 0, 1, 1, 1, 1, 1, 2, 3, 3, 2, 3, 2, 3, 2, 0, 0, 3, 1, 1,
#        0, 1, 0, 0, 3, 3, 2, 3, 2, 3, 3, 2, 1, 2, 3, 0, 2, 3, 0, 3, 1, 2,
#        0, 2, 2, 0, 3, 0, 3, 3, 3, 2, 0, 0, 1, 3, 3, 3, 3, 0, 3, 2, 3, 3,
#        1, 2, 1, 1, 0, 1, 3, 3, 3, 1, 0, 0, 3, 0, 1, 3, 1, 3, 0, 0, 1, 1,
#        1, 3, 3, 1, 0, 0, 1, 3, 1, 1, 3, 2, 1, 2, 1, 0, 2, 2, 1, 1, 1, 2,
#        2, 0, 2, 2, 0, 1, 1, 1, 0, 2, 1, 3, 2, 0, 2, 2, 0, 3, 3, 3, 2, 0,
#        2, 1])

# %%
plt.scatter(X[:,0] , X[:,1] , c = clf.labels_)

# %%
x1,x2 = np.meshgrid(np.arange(0,1,0.01),np.arange(0,1,0.01))

# %%
Z  = clf.predict(np.c_[x1.ravel(),x2.ravel()])
Z = Z.reshape(x1.shape)

# %%
plt.contourf(x1 , x2 , Z , alpha = 0.3)

plt.scatter(X[:,0] , X[:,1] , c = clf.labels_)

# %% [markdown]
# wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww
#
#
# 製造一個 "正常的" 數據
# n_features 是指參數要幾個, n_classes 是你要分成幾類

# %%
from sklearn.datasets import make_classification


x, y = make_classification(n_features=2, n_redundant=0, 
                           n_informative=2, 
                           n_clusters_per_class=1, n_classes=4,
                           random_state=98765)

# %%
plt.scatter(x[:,0], x[:,1], s=50, c=y)

# %%
from sklearn.svm import SVC
clf = SVC()

# %%
clf.fit(x,y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plt.scatter(x[:,0], x[:,1], s=50, c=clf.predict(x))

# %%
x1, x2 = np.meshgrid(np.arange(-4,4,0.05), np.arange(-3,4,0.05))
X = np.c_[x1.ravel(),x2.ravel()]
Z = clf.predict(X)
z = Z.reshape(x1.shape)

# %%
plt.contourf(x1, x2, z, alpha=0.3)
plt.scatter(x[:,0], x[:,1], s=100, c=y)
