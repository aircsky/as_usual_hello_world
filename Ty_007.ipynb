# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(100) * 5 + 10

# %%
y
# Out:
# array([10.14153072, 11.74895077, 14.53251057, 12.91807384, 13.16326817,
#        14.10606576, 14.66807173, 12.95224671, 11.13497124, 10.56289386,
#        14.24463791, 14.35952785, 10.00959464, 10.59381081, 12.36814436,
#        14.42934141, 10.57634436, 10.13151878, 10.15079133, 13.29360874,
#        11.06393797, 11.5243479 , 10.54682615, 14.67517033, 12.25749583,
#        10.83771127, 14.94150399, 12.79889126, 10.26872188, 11.99876656,
#        10.88682999, 12.98793479, 12.32158381, 11.99060042, 12.9501375 ,
#        10.6232678 , 11.01061027, 13.04123598, 14.14640731, 13.87330474,
#        12.95792678, 13.32260021, 10.5661424 , 12.14268858, 11.08498699,
#        10.21817861, 10.73869036, 10.13701719, 11.55688654, 10.59789238,
#        11.60286007, 12.05972222, 12.73380758, 11.0875818 , 13.63616224,
#        13.38751427, 13.06284517, 12.49301524, 11.51331574, 14.0474414 ,
#        11.19266712, 14.80655369, 12.35825677, 14.83078113, 14.74575126,
#        14.43529224, 12.7084484 , 10.59998688, 11.98255952, 10.40837273,
#        11.76180581, 11.45042093, 11.36295674, 12.9342381 , 13.57538268,
#        12.92865314, 14.44378291, 13.49913532, 10.97346365, 10.70708519,
#        12.51887882, 10.33523692, 10.64679087, 10.28446065, 13.04863613,
#        11.1827503 , 13.32861527, 13.50902231, 14.93560108, 10.05611129,
#        13.22573449, 13.50902091, 14.18327332, 10.77486857, 11.5720031 ,
#        11.35119466, 12.23265507, 10.31358705, 10.86000102, 11.93233907])

# %%
plt.plot(y)

# %%
x = np.linspace(0,50,101)

# %%
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#         5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#        11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. ,
#        16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5, 20. , 20.5, 21. , 21.5,
#        22. , 22.5, 23. , 23.5, 24. , 24.5, 25. , 25.5, 26. , 26.5, 27. ,
#        27.5, 28. , 28.5, 29. , 29.5, 30. , 30.5, 31. , 31.5, 32. , 32.5,
#        33. , 33.5, 34. , 34.5, 35. , 35.5, 36. , 36.5, 37. , 37.5, 38. ,
#        38.5, 39. , 39.5, 40. , 40.5, 41. , 41.5, 42. , 42.5, 43. , 43.5,
#        44. , 44.5, 45. , 45.5, 46. , 46.5, 47. , 47.5, 48. , 48.5, 49. ,
#        49.5, 50. ])

# %%
plt.plot(x , np.sin(x)+x)

# %%
plt.plot(x , np.sin(x)+x)
plt.plot(x , np.cos(x)+x)
