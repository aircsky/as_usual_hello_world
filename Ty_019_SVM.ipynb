# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([[-3,2],[-6,5],[3,-4],[2,-8]])
y = np.array([1,1,2,2])

# %%
plt.scatter([-3,-6,3,2],[2,5,-4,-8], c=y)

# %%
x
# Out:
# array([[-3,  2],
#        [-6,  5],
#        [ 3, -4],
#        [ 2, -8]])

# %%
x[:,0]
# Out:
# array([-3, -6,  3,  2])

# %%
plt.scatter(x[:,0],x[:,1], c=y ,s=100)

# %%
from sklearn.svm import SVC

# %% [markdown]
# clf = 分類機

# %%
clf = SVC()

# %%
clf.fit(x,y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
x2 = [-3,-2,-1,0,1]
y2 = [-6,-4,-2,0,2]

# %%
X , Y = np.meshgrid(x2,y2)

# %%
X
# Out:
# array([[-3, -2, -1,  0,  1],
#        [-3, -2, -1,  0,  1],
#        [-3, -2, -1,  0,  1],
#        [-3, -2, -1,  0,  1],
#        [-3, -2, -1,  0,  1]])

# %%
Y
# Out:
# array([[-6, -6, -6, -6, -6],
#        [-4, -4, -4, -4, -4],
#        [-2, -2, -2, -2, -2],
#        [ 0,  0,  0,  0,  0],
#        [ 2,  2,  2,  2,  2]])

# %%
X , Y = np.meshgrid(np.linspace(-6,3,30),np.linspace(-8,5,30))

# %% [markdown]
# X.ravel
# Y.ravel
#
# 拉平成一維向量

# %%
X = X.ravel()
Y = Y.ravel()

# %%
plt.scatter(X,Y)

# %% [markdown]
# zip = 把x,y 壓在一起
# x = [1,2,3,4]
# y = [5,6,7,8]
# zip = [(1,5)(2,6)(3,7)(4,8)]

# %%
Ans = clf.predict(list(zip(X,Y)))

# %%
plt.scatter(X,Y,c=Ans)
